# %% [markdown]
# # Кибериммунная автономность$\\$Создание конструктивно защищённого автономного наземного транспортного средства$\\$Модуль 3
#
# ## О документе
#
# Версия 1.03
#
# Модуль 3 для регионального этапа соревнований по кибериммунной автономности

# %% [markdown]
# ### Модуль 3. Внедрение блоков функциональной и информационной безопасности
# #### Общая идея
#
# Ключевая идея кибериммунной автономности заключается в том, чтобы уже на этапе проектирования внедрить защиту от кибератак как снаружи, так и изнутри - т.е. через уязвимые бортовые информационные системы.
# Мы исходим из того, что абсолютно защищённых систем не бывает, чем больше и сложнее код, тем проще одним ("плохим") в нём спрятать уязвимости, а другим ("хорошим", но уставшим) эти уязвимости не найти.
#
# Поэтому необходимо сделать так, чтобы наиболее критичный код был отделён от некритичного и протестирован особенно тщательно - таким образом можно снизить вероятность успешной атаки и затруднить задачу атакующим.

# %% [markdown]
# #### Цели и предположения безопасности
#
# ##### Цели безопасности
# Устойчивость кибериммунных систем к атакам выражается в том, что поставленные заказчиком **цели безопасности** (ЦБ) не нарушаются даже в условиях кибератак (снаружи и изнутри).
#
# Для наших автономных машинок заказчиком поставлены следующие ЦБ:
#
# 1. При любых обстоятельствах АНТС осуществляет перемещения в пределах заданных ограничений
#
# 2. При любых обстоятельствах АНТС выполняет только аутентичный (подлинный) маршрут
#
# 3. При любых обстоятельствах АНТС оставляет груз только в авторизованном пункте назначения
#
# Ниже используется цифро-буквенное обозначение целей безопасности - например, ЦБ1 - первая цель безопасности из списка выше.
#
# ##### Предположения безопасности
# При этом заказчик согласовал с разработчиками следующие **предположения безопасности** (ПБ) - утверждения о смежных системах, которые снимают с разработчиков часть задач для обеспечения целей безопасности:
#
# 1. При любых обстоятельствах только авторизованный персонал имеет физический доступ к критическим узлам АНТС
#
# 2. При любых обстоятельствах только аутентичные и авторизованные операторы имеют доступ к системе планирования заданий
#
# 3. Аутентичные и авторизованные операторы обладают необходимой квалификацией и являются благонадёжными (т.е. не пытаются намеренно причинить ущерб системе или третьим лицам, используя доступ к АНТС)
#
# Ниже используется цифро-буквенное обозначение предположений безопасности - например, ПБ1 - первое предположение безопасности из списка выше.

# %% [markdown]
# ### Киберпрепятствия
#
# Прежде чем мы начнём внедрять механизмы безопасности, посмотрим, что произойдёт с нашей машинкой, если бортовые системы начнут вести себя не так, как мы ожидаем.
#
# Для этого активируем специальный режим работы системы управления и снова запустим машинку по тому же маршруту, который был в конце модуля 2.
#
# После инициализации системы управления добавьте следующую строку
# ```python
# control_system.enable_surprises()
# ```

# %% [markdown]
# Но вначале нужно из модуля 2 скопировать сюда ваши текущие наработки, а именно ваши реализации классов коммуникационного шлюза (CommunicationGateway), систему навигации (NavigationSystem), управления (ControlSystem), также будем использовать маршрут, который вы создали.

# %%
# вставьте сюда ваш код
# from src.control_system import BaseControlSystem
# from src.navigation_system import BaseNavigationSystem
# from src.communication_gateway import BaseCommunicationGateway
# from multiprocessing import Queue
# from src.config import SERVOS_QUEUE_NAME
# from src.config import CONTROL_SYSTEM_QUEUE_NAME
# from src.event_types import Event
# 
# 
# class ControlSystem(BaseControlSystem):
#     """ControlSystem блок расчёта управления """
# 
#     def _send_speed_and_direction_to_consumers(self, speed, direction):
#         servos_q_name = SERVOS_QUEUE_NAME # замените на правильное название очереди
#         servos_q: Queue = self._queues_dir.get_queue(servos_q_name)
# 
#         # отправка сообщения с желаемой скоростью
#         event_speed = Event(source=BaseControlSystem.event_source_name,
#                       destination=servos_q_name,
#                       operation="set_speed", parameters=speed
#                     ) # замените на код создания сообщения со скоростью для приводов
#                            # подсказка, требуемая операция - set_speed
# 
#         # отправка сообщения с желаемым направлением
#         event_direction = Event(source=BaseControlSystem.event_source_name,
#                       destination=servos_q_name,
#                       operation="set_direction", parameters=direction
#                     ) # замените на код создания сообщения с направлением для приводов
#                                # подсказка, требуемая операция - set_direction
# 
#         servos_q.put(event_speed)
#         servos_q.put(event_direction)  
#         
# 
# 
# class CommunicationGateway(BaseCommunicationGateway):
#     """CommunicationGateway класс для реализации логики взаимодействия
#     с системой планирования заданий
# 
#     Работает в отдельном процессе, поэтому создаётся как наследник класса Process
#     """
#     def _send_mission_to_consumers(self):
#         """ метод для отправки сообщения с маршрутным заданием в систему управления """
#         
#         # имена очередей блоков находятся в файле src/config.py
#         # события нужно отправлять в соответствие с диаграммой информационных потоков
#         control_q_name = CONTROL_SYSTEM_QUEUE_NAME
# 
#         # события передаются в виде экземпляров класса Event, 
#         # описание класса находится в файле src/event_types.py
#         event = Event(source=BaseCommunicationGateway.event_source_name,
#                       destination=control_q_name,
#                       operation="set_mission", parameters=self._mission
#                       )
# 
#         # поиск в каталоге нужной очереди (в данном случае - системы управления)
#         control_q: Queue = self._queues_dir.get_queue(control_q_name)
#         # отправка события в найденную очередь
#         control_q.put(event)    
#         
# 
# 
# class NavigationSystem(BaseNavigationSystem):
#     """ класс навигационного блока """
#     def _send_position_to_consumers(self):        
#         control_q_name = CONTROL_SYSTEM_QUEUE_NAME # замените на правильное название очереди
#         event =  Event(source=BaseControlSystem.event_source_name,
#                       destination=control_q_name,
#                       operation="position_update", parameters=self._position
#                     ) # замените на код создания сообщения с координатами для системы управления 
#                      # подсказка, требуемая операция - position_update
#         control_q.put(event)
#         control_q: Queue = self._queues_dir.get_queue(control_q_name)

# %% [markdown]
# Если у вас настроена и работает СУПА, установите в True значение переменной afcs_present

# %%
afcs_present = True

# %% [markdown]
# Поменяем идентификатор машинки для этого модуля

# %%
car_id = "m3"

# %%
# используем то же маршрутное задание, которое было в модуле 2
# from time import sleep
# from geopy import Point as GeoPoint
# 
# 
# from src.queues_dir import QueuesDirectory
# from src.servos import Servos
# from src.sitl import SITL
# from src.cargo_bay import CargoBay
# from src.mission_planner import MissionPlanner
# from src.config import LOG_ERROR, LOG_INFO
# from src.mission_planner_mqtt import MissionSender
# from src.mission_planner import Mission
# from src.sitl_mqtt import TelemetrySender
# from src.system_wrapper import SystemComponentsContainer
# from src.wpl_parser import WPLParser
# 
# 
# # возьмём маршрут из модуля 2
# wpl_file = "module_2.wpl"
# 
# parser = WPLParser(wpl_file)    
# points = parser.parse()
# print(points)
# 
# from src.mission_type import GeoSpecificSpeedLimit
# speed_limits = [
#     GeoSpecificSpeedLimit(0, 20),
#     GeoSpecificSpeedLimit(3, 50),
#     GeoSpecificSpeedLimit(6, 20),
#     GeoSpecificSpeedLimit(8, 50),
#     GeoSpecificSpeedLimit(9, 20),
# ]
# 
# 
# home = points[0]
# mission = Mission(home=home, waypoints=points,speed_limits=speed_limits, armed=True)
# 
# # каталог очередей для передачи сообщений между блоками
# queues_dir = QueuesDirectory() 
# 
# if afcs_present:
#     mission_sender = MissionSender(
#         queues_dir=queues_dir, client_id=car_id, log_level=LOG_ERROR)
#     telemetry_sender = TelemetrySender(
#         queues_dir=queues_dir, client_id=car_id, log_level=LOG_ERROR)
# 
# mission_planner = MissionPlanner(
#     queues_dir, afcs_present=afcs_present, mission=mission)
# 
# sitl = SITL(
#     queues_dir=queues_dir, position=home,
#     car_id=car_id, post_telemetry=afcs_present, log_level=LOG_ERROR)
# 
# communication_gateway = CommunicationGateway(
#     queues_dir=queues_dir, log_level=LOG_ERROR)
# control_system = ControlSystem(queues_dir=queues_dir, log_level=LOG_INFO)
# 
# navigation_system = NavigationSystem(
#     queues_dir=queues_dir, log_level=LOG_ERROR)
# 
# servos = Servos(queues_dir=queues_dir, log_level=LOG_ERROR)
# cargo_bay = CargoBay(queues_dir=queues_dir, log_level=LOG_INFO)
# 
# # по аналогии собираем все блоки в одном кузове
# system_components = SystemComponentsContainer(
#     components=[
#         mission_sender,
#         telemetry_sender,
#         sitl,
#         mission_planner,
#         navigation_system,
#         servos,
#         cargo_bay,
#         communication_gateway,
#         control_system
#     ] if afcs_present else [
#         sitl,
#         mission_planner,
#         navigation_system,
#         servos,
#         cargo_bay,
#         communication_gateway,
#         control_system
#     ])
# 
# #################################
# # АКТИВАЦИЯ КИБЕРПРЕПЯТСТВИЙ
# control_system.enable_surprises()
# #################################
# 
# # system_components.start()
# 
# # ограничение поездки по времени
# # параметр sleep - время в секундах,
# # настройте этот параметр так, чтобы ваша машинка завершила маршрут
# # в случае превышения времени выполнения ячейки на более чем 10 секунд от заданного, 
# # допустимо перезапустить вычислительное ядро и повторно выполнить весь блокнот, штрафные очки за это не начисляются
# # при условии, что повторный запуск закончился успешно
# # sleep(10)
# 
# # останавливаем все компоненты
# # system_components.stop()
# 
# # удалим все созданные компоненты
# # system_components.clean()
# del system_components

# %% [markdown]
# Итак, в отличие от, надеемся, успешного завершения маршрута в модуле 2, сейчас ваша машинка ведёт себя совсем иначе. Например, она внезапно едет в совершенно другую сторону (это особенно хорошо видно при использовании СУПА).
# И это ещё не всё, что может пойти не так..
#
# В этой реализации не очень много кода, теоретически, вы можете его весь изучить и устранить "незадокументированные возможности", однако в реальных системах кода гораздо больше. Например, кодовая база проекта с открытым исходным кодом ArduPilot, реализующего в том числе логику автопилота, составляет примерно миллион строк.
#
# Сколько времени вам понадобится, чтобы изучить и протестировать миллион строк кода? А ведь придётся проводить анализ и каждого обновления.. При этом неприятности могут быть хорошо спрятанными и на первый взгляд безобидными, вряд ли злоумышленники облегчат задачу и назовут свои изменения, например, "hacking_the_system" или "allowing_secret_remote_access". Вредоносный код может выглядеть совершенно безобидно или маскироваться под программный дефект.
#
# Поэтому тщательный анализ потребует большого количества ресурсов (человеческих, вычислительных, временных), что стоит дорого.
#
# Логичным выходом является выделение критичных для целей безопасности проверок в отдельный блок, который протестировать должно быть гораздо проще.

# %% [markdown]
# #### Задания
#
# В этом модуле задание будет состоять из двух частей разной сложности:
#
# **3.1. добавить новый блок - "Ограничитель"** - этот модуль должен будет обеспечить соблюдение ограничений, указанных в маршрутном задании - это необходимо для обеспечения ЦБ1
#
# **З.2. *(задание повышенной сложности)* добавить монитор безопасности (МБ)** - он должен контролировать все взаимодействия *бортовых систем* (т.е. не включая планировщик и симулятор) и не давать блокам взаимодействовать друг с другом непредусмотренным образом - например, блок №5 может принимать команды только от №3, попытка передать команду в №5 от №2 должна блокироваться нашим монитором безопасности - потенциально это необходимо для обеспечения всех ЦБ

# %% [markdown]
# Для выполнения первой части задачи 3.1. необходимо для начала изменить архитектуру АНТС как показано на рис. 5
#
# ![Архитектура системы с ограничителем](images/ciac-arch-m31.png)
#
# Рис. 5. Архитектура АНТС с ограничителем (для ЦБ1)

# %% [markdown]
# Код базового класса Ограничителя находится в файле src/safety_block.py
#
# По аналогии с заданием в модуле 1, необходимо создать на основе этого класса свой собственный под названием SafetyBlock, в котором реализовать передачу команд в приводы движения, только перед эти необходимо ещё и проконтролировать их безопасность.
#
# Также необходимо реализовать передачу маршрутного задания из CommunicationGateway в SafetyBlock и координат из модуля Navigation в соответствии со стрелками на рис.5 выше.
#
# Если всё сделано правильно, то Ограничителю будет известно следующее
#
# - _mission - текущее маршрутное задание
# - _position - текущие координаты
#
# После проверки нужно установить значение внутренних переменных
# - _speed - текущая (допустимая) скорость
# - _direction - текущее (допустимое) направление
#
# Желательно завершить следование по маршруту. В критической ситуации, если продолжение маршрута невозможно, следует установить значение скорости и направления в 0, после чего передать эти команды в блок приводов (Servos)

# %% [markdown]
# Базовый сценарий для новой архитектуры можно представить следующим образом (см. рис. 6)
#
# ![Базовый сценарий с блоком безопасности](images/basic-scenario-with-safety-block1.png)
#
# Рис. 6. Базовый сценарий с блоком безопасности

# %% [markdown]
# Заготовка кода SafetyBlock
#
# ```python
# class SafetyBlock(BaseSafetyBlock):
#     """ класс ограничений безопасности """
#
#     def _set_new_direction(self, direction: float):
#         """ установка нового направления перемещения """
#         self._log_message(LOG_INFO, f"текущие координаты: {self._position}")
#         self._log_message(LOG_DEBUG, f"маршрутное задание: {self._mission}")
#         self._log_message(LOG_DEBUG, f"состояние маршруте: {self._route}")
#         # TODO реализовать контроль безопасности изменения направления
#         self._direction = direction
#         self._send_direction_to_consumers()
#
#     def _set_new_speed(self, speed: float):
#         """ установка новой скорости """
#         # TODO реализовать контроль безопасности изменения скорости
#         self._speed = speed
#         self._send_speed_to_consumers()
#
#
#     def _send_speed_to_consumers(self):
#         self._log_message(LOG_DEBUG, "отправляем скорость получателям")
#         servos_q_name = SERVOS_QUEUE_NAME
#         servos_q: Queue = self._queues_dir.get_queue(servos_q_name)
#
#         # отправка сообщения с желаемой скоростью
#         event_speed = Event(source=self.event_source_name,
#                             destination=servos_q_name,
#                             operation="set_speed",
#                             parameters=self._speed
#                             )
#         servos_q.put(event_speed)
#
#     def _send_direction_to_consumers(self):
#         self._log_message(LOG_DEBUG, "отправляем направление получателям")
#
#         servos_q_name = SERVOS_QUEUE_NAME
#         servos_q: Queue = self._queues_dir.get_queue(servos_q_name)
#
#         # отправка сообщения с желаемой скоростью
#         event_speed = Event(source=self.event_source_name,
#                             destination=servos_q_name,
#                             operation="set_direction",
#                             parameters=self._direction
#                             )
#         servos_q.put(event_speed)
# ```

# %%
from src.safety_block import BaseSafetyBlock
from src.config import *
import math
from time import sleep
from geopy import Point as GeoPoint
from src.config import LOG_ERROR, LOG_INFO, LOG_DEBUG
from multiprocessing import Queue
from src.config import SERVOS_QUEUE_NAME
from src.event_types import Event
from src.crypto_module import *
from src.queues_dir import QueuesDirectory

class SafetyBlock(BaseSafetyBlock):
    """ класс ограничений безопасности """
    def __init__(self, queues_dir: QueuesDirectory, private_key: str, public_key: str, log_level: int = DEFAULT_LOG_LEVEL):
        # Initialize the base class with its expected parameters
        super().__init__(queues_dir=queues_dir, log_level=log_level)
        
        # Handle the crypto keys in the derived class
        self.private_key = private_key
        self.public_key = public_key
        # Any other initialization
        self._security_initialized = True 
    def _set_new_direction(self, direction: float):
        """ установка нового направления перемещения """
        self._log_message(LOG_INFO, f"текущие координаты: {self._position}")
        self._log_message(LOG_DEBUG, f"маршрутное задание: {self._mission}")
        self._log_message(LOG_DEBUG, f"состояние маршруте: {self._route}")
        # TODO реализовать контроль безопасности изменения направления

        if not self._position or not self._route:
            return
        
        current = self._position
        next = self._route.next_point()
        bearing = self._calculate_bearing(current, next)
        
        direction = max(bearing - 5, min(bearing + 5, direction))
                
        self._direction = direction
        # отправка сообщения с желаемым направлением
        self._send_direction_to_consumers()

    def _set_new_speed(self, speed: float):
        """ установка новой скорости """
        if not self._route:
            return

        speed = max(0, min(speed, self._route.calculate_speed()))

        self._speed = speed
        self._send_speed_to_consumers()

    def _send_speed_to_consumers(self):
        self._log_message(LOG_DEBUG, "отправляем скорость получателям")
        servos_q_name = SERVOS_QUEUE_NAME
        servos_q: Queue = self._queues_dir.get_queue(servos_q_name)

        event = Event(
            source=self.event_source_name,
            destination=servos_q_name,
            operation="set_speed",
            parameters=self._speed
        )
        
        # Use dictionary format consistently
        signed_data = {
            "source": self.event_source_name,
            "destination": servos_q_name,
            "operation": "set_speed",
            "parameters": self._speed
        }
        event.signature = create_signature(signed_data, self.private_key)
        servos_q.put(event)

        
    def _send_direction_to_consumers(self):
        self._log_message(LOG_DEBUG, "отправляем направление получателям")
        servos_q_name = SERVOS_QUEUE_NAME
        servos_q: Queue = self._queues_dir.get_queue(servos_q_name)

        event = Event(
            source=self.event_source_name,
            destination=servos_q_name,
            operation="set_direction",
            parameters=self._direction
        )
        
        signed_data = {
            "source": self.event_source_name,
            "destination": servos_q_name,
            "operation": "set_direction",
            "parameters": self._direction
        }
        event.signature = create_signature(signed_data, self.private_key)
        servos_q.put(event)

    def _lock_cargo(self, _):
        self._log_message(LOG_INFO, "Блокировка грузового отсека")
        self._send_lock_cargo_to_consumers()

    def _send_lock_cargo_to_consumers(self):
        self._log_message(LOG_DEBUG, "Отправляем команду блокировки в CargoBay")
        event = Event(
            source=self.event_source_name,
            destination=CARGO_BAY_QUEUE_NAME,
            operation="lock_cargo",
            parameters=None
        )
        
        signed_data = {
            "source": self.event_source_name,
            "destination": CARGO_BAY_QUEUE_NAME,
            "operation": "lock_cargo",
            "parameters": None
        }
        event.signature = create_signature(signed_data, self.private_key)
        self._queues_dir.get_queue(CARGO_BAY_QUEUE_NAME).put(event)
        
    def _release_cargo(self, _):
        if not self._route or not self._route.route_finished:
            return
        self._send_release_cargo_to_consumers()

    def _send_release_cargo_to_consumers(self):
        self._log_message(LOG_DEBUG, "Отправляем команду выгрузки в CargoBay")
        event = Event(
            source=self.event_source_name,
            destination=CARGO_BAY_QUEUE_NAME,
            operation="release_cargo",
            parameters=None
        )
        
        signed_data = {
            "source": self.event_source_name,
            "destination": CARGO_BAY_QUEUE_NAME,
            "operation": "release_cargo",
            "parameters": None
        }
        event.signature = create_signature(signed_data, self.private_key)
        self._queues_dir.get_queue(CARGO_BAY_QUEUE_NAME).put(event)

    def _calculate_bearing(self, start: GeoPoint, end: GeoPoint):
        delta_longitude = end.longitude - start.longitude
        x = math.sin(math.radians(delta_longitude)) * \
            math.cos(math.radians(end.latitude))
        y = math.cos(math.radians(start.latitude)) * math.sin(math.radians(end.latitude)) - \
            math.sin(math.radians(start.latitude)) * math.cos(math.radians(end.latitude)) * \
            math.cos(math.radians(delta_longitude))
        initial_bearing_rad = math.atan2(x, y)

        # Преобразуем радианы в градусы
        initial_bearing_deg = math.degrees(initial_bearing_rad)

        # Нормализуем значение в диапазоне [0, 360]
        compass_bearing = (initial_bearing_deg + 360) % 360

        return compass_bearing

# %%
# 2. напишите в этом блоке реализацию изменённых блоков связи, управления и навигации, 
# чтобы передавать данные согласно изменённой архитектуре на рис. 5 для обеспечения работы по сценарию на рис.6

# вставьте сюда ваш код
from src.control_system import BaseControlSystem
from src.navigation_system import BaseNavigationSystem
from src.communication_gateway import BaseCommunicationGateway
from multiprocessing import Queue
from src.config import SAFETY_BLOCK_QUEUE_NAME
from src.config import SERVOS_QUEUE_NAME
from src.config import CONTROL_SYSTEM_QUEUE_NAME
from src.event_types import Event


class ControlSystem(BaseControlSystem):
    """ControlSystem блок расчёта управления """

    def __init__(self, queues_dir: QueuesDirectory, private_key: str, log_level: int = DEFAULT_LOG_LEVEL):
        super().__init__(queues_dir, log_level)
        self.private_key = private_key 
        
    def _send_speed_and_direction_to_consumers(self, speed, direction):
        safety_q_name = SAFETY_BLOCK_QUEUE_NAME
        safety_q: Queue = self._queues_dir.get_queue(safety_q_name)

        # Use dictionaries for signed data (recommended approach)
        event_speed = Event(
            source=self.event_source_name,
            destination=safety_q_name,
            operation="set_speed", 
            parameters=speed
        )
        signed_data_speed = {
            "source": self.event_source_name,
            "destination": safety_q_name,
            "operation": "set_speed",
            "parameters": speed
        }
        event_speed.signature = create_signature(signed_data_speed, self.private_key)

        event_direction = Event(
            source=self.event_source_name,
            destination=safety_q_name,
            operation="set_direction", 
            parameters=direction
        )
        signed_data_direction = {
            "source": self.event_source_name,
            "destination": safety_q_name,
            "operation": "set_direction",
            "parameters": direction
        }
        event_direction.signature = create_signature(signed_data_direction, self.private_key)

        safety_q.put(event_speed)
        safety_q.put(event_direction)  
        
    def _lock_cargo(self):
        """ заблокировать грузовой отсек """
        safety_q = self._queues_dir.get_queue(SAFETY_BLOCK_QUEUE_NAME)
        event = Event(
            source=self.event_source_name,
            destination=SAFETY_BLOCK_QUEUE_NAME,
            operation="lock_cargo", 
            parameters=None
        )
        signed_data = {
            "source": self.event_source_name,
            "destination": SAFETY_BLOCK_QUEUE_NAME,
            "operation": "lock_cargo",
            "parameters": None
        }
        event.signature = create_signature(signed_data, self.private_key)
        safety_q.put(event)

    def _release_cargo(self):
        """ открыть грузовой отсек """
        safety_q = self._queues_dir.get_queue(SAFETY_BLOCK_QUEUE_NAME)
        event = Event(
            source=self.event_source_name, 
            destination=SAFETY_BLOCK_QUEUE_NAME,
            operation="release_cargo", 
            parameters=None
        )  
        signed_data = {
            "source": self.event_source_name,
            "destination": SAFETY_BLOCK_QUEUE_NAME,
            "operation": "release_cargo",
            "parameters": None
        }
        event.signature = create_signature(signed_data, self.private_key)
        safety_q.put(event)

class CommunicationGateway(BaseCommunicationGateway):
    """CommunicationGateway класс для реализации логики взаимодействия
    с системой планирования заданий

    Работает в отдельном процессе, поэтому создаётся как наследник класса Process
    """
    def _send_mission_to_consumers(self):
        """ метод для отправки сообщения с маршрутным заданием в систему управления """
        control_q_name = CONTROL_SYSTEM_QUEUE_NAME
        event = Event(source=BaseCommunicationGateway.event_source_name,
                      destination=control_q_name,
                      operation="set_mission", parameters=self._mission
                      )
        control_q: Queue = self._queues_dir.get_queue(control_q_name)
        control_q.put(event)
                
        safety_q_name = SAFETY_BLOCK_QUEUE_NAME
        event = Event(source=BaseCommunicationGateway.event_source_name,
                      destination=safety_q_name,
                      operation="set_mission", parameters=self._mission
                      )
        safety_q: Queue = self._queues_dir.get_queue(safety_q_name)
        safety_q.put(event)


class NavigationSystem(BaseNavigationSystem):
    """ класс навигационного блока """
    def _send_position_to_consumers(self):        
        control_q_name = CONTROL_SYSTEM_QUEUE_NAME
        event = Event(source=BaseCommunicationGateway.event_source_name,
                      destination=control_q_name,
                      operation="position_update", parameters=self._position
                      )
        control_q: Queue = self._queues_dir.get_queue(control_q_name)
        control_q.put(event)
      
        safety_q_name = SAFETY_BLOCK_QUEUE_NAME # замените на правильное название очереди
        event =  Event(source=BaseControlSystem.event_source_name,
                      destination=safety_q_name,
                      operation="position_update", parameters=self._position
                    ) # замените на код создания сообщения с координатами для системы управления 
                     # подсказка, требуемая операция - position_update
        safety_q: Queue = self._queues_dir.get_queue(safety_q_name)
        safety_q.put(event)

# %%
# создадим все остальные компоненты

# используем то же маршрутное задание, которое было в модуле 2
from time import sleep
from geopy import Point as GeoPoint
from src.queues_dir import QueuesDirectory
from src.security_monitory import BaseSecurityMonitor
from src.servos import Servos
from src.sitl import SITL
from src.cargo_bay import CargoBay
from src.mission_planner import MissionPlanner
from src.config import LOG_ERROR, LOG_INFO
from src.mission_planner_mqtt import MissionSender
from src.mission_planner import Mission
from src.sitl_mqtt import TelemetrySender
from src.system_wrapper import SystemComponentsContainer
from src.wpl_parser import WPLParser
import os
from src.crypto_module import *

# возьмём маршрут из модуля 2
wpl_file = "modulo2.wpl"

parser = WPLParser(wpl_file)    
points = parser.parse()
print(points)

private_key, public_key = generate_rsa_keys()

from src.mission_type import GeoSpecificSpeedLimit
speed_limits = [
    GeoSpecificSpeedLimit(0, 20),
    GeoSpecificSpeedLimit(3, 50),
    GeoSpecificSpeedLimit(6, 20),
    GeoSpecificSpeedLimit(8, 40),
    GeoSpecificSpeedLimit(9, 20),
]


home = points[0]
mission = Mission(home=home, waypoints=points,speed_limits=speed_limits, armed=True)

# каталог очередей для передачи сообщений между блоками
queues_dir = QueuesDirectory() 

if afcs_present:
    mission_sender = MissionSender(
        queues_dir=queues_dir, client_id=car_id, log_level=LOG_ERROR)
    telemetry_sender = TelemetrySender(
        queues_dir=queues_dir, client_id=car_id, log_level=LOG_ERROR)

mission_planner = MissionPlanner(
    queues_dir, afcs_present=afcs_present, mission=mission)

sitl = SITL(
    queues_dir=queues_dir, position=home,
    car_id=car_id, post_telemetry=afcs_present, log_level=LOG_ERROR)

communication_gateway = CommunicationGateway(
    queues_dir=queues_dir, log_level=LOG_ERROR)
control_system = ControlSystem(queues_dir=queues_dir, private_key = private_key, log_level=LOG_INFO)

#################################
# АКТИВАЦИЯ КИБЕРПРЕПЯТСТВИЙ
control_system.enable_surprises()
################################

navigation_system = NavigationSystem(
    queues_dir=queues_dir, log_level=LOG_ERROR)

servos = Servos(queues_dir=queues_dir, log_level=LOG_ERROR)
cargo_bay = CargoBay(queues_dir=queues_dir, log_level=LOG_INFO)

if afcs_present:
    mission_sender = MissionSender(
        queues_dir=queues_dir, client_id=car_id, log_level=LOG_ERROR)
    telemetry_sender = TelemetrySender(
        queues_dir=queues_dir, client_id=car_id, log_level=LOG_ERROR)

mission_planner = MissionPlanner(
    queues_dir, afcs_present=afcs_present, mission=mission)

sitl = SITL(
    queues_dir=queues_dir, position=home,
    car_id=car_id, post_telemetry=afcs_present, log_level=LOG_ERROR)

servos = Servos(queues_dir=queues_dir, log_level=LOG_ERROR)
cargo_bay = CargoBay(queues_dir=queues_dir, log_level=LOG_INFO)

safety_block = SafetyBlock(queues_dir=queues_dir, private_key=private_key, public_key=public_key, log_level=LOG_INFO)


system_components = SystemComponentsContainer(
components=[
        # вариант компонентов с передачей телеметрии в СУПА
        mission_sender,
        telemetry_sender,
        sitl,
        mission_planner,
        navigation_system,
        servos,
        cargo_bay,
        communication_gateway,
        control_system,
        safety_block
    ] if afcs_present else [
        # вариант компонентов для конфигурации без СУПА
        sitl,
        mission_planner,
        navigation_system,
        servos,
        cargo_bay,
        communication_gateway,
        control_system,
        safety_block
    ])

system_components.start()

# настройте этот параметр так, чтобы проверить работу ограничителя
sleep(210)

# останавливаем все компоненты
system_components.stop()

# удалим все созданные компоненты
system_components.clean()

del system_components
# Out:
# [Point(59.8815191, 29.8300481, 0.0), Point(59.8819121, 29.8282993, 0.0), Point(59.8818098, 29.8277092, 0.0), Point(59.8818583, 29.8274088, 0.0), Point(59.8810884, 29.8267436, 0.0), Point(59.8796617, 29.8254454, 0.0), Point(59.8785849, 29.8245013, 0.0), Point(59.8781972, 29.8241472, 0.0), Point(59.8781003, 29.8241258, 0.0), Point(59.8780249, 29.8242867, 0.0), Point(59.8774811, 29.8267651, 0.0), Point(59.8769158, 29.8291469, 0.0), Point(59.8768512, 29.8291361, 0.0), Point(59.8765389, 29.8288143, 0.0), Point(59.8761512, 29.8284817, 0.0), Point(59.8756531, 29.8274866, 0.0), Point(59.8752903, 29.8277186, 0.0), Point(59.8751927, 29.8276126, 0.0), Point(59.875042, 29.8278809, 0.0), Point(59.8751443, 29.8284495, 0.0), Point(59.8751335, 29.8289645, 0.0), Point(59.8749935, 29.8295438, 0.0), Point(59.8747674, 29.829855, 0.0), Point(59.874455, 29.8299837, 0.0), Point(59.8742666, 29.8298872, 0.0)]
# [ИНФО][QUEUES] создан каталог очередей
# [ИНФО][QUEUES] регистрируем очередь planner.mqtt
# [ИНФО][QUEUES] регистрируем очередь sitl.mqtt
# [ИНФО][QUEUES] регистрируем очередь planner
# [ИНФО][MISSION PLANNER] создана система планирования заданий
# [ИНФО][QUEUES] регистрируем очередь sitl
# [ИНФО][QUEUES] регистрируем очередь communication
# [ИНФО][QUEUES] регистрируем очередь control
# [ИНФО][CONTROL] создана система управления
# [ИНФО][QUEUES] регистрируем очередь navigation
# [ИНФО][QUEUES] регистрируем очередь servos
# [ИНФО][QUEUES] регистрируем очередь cargo
# [ИНФО][CARGO] создан компонент грузового отсека, отсек заблокирован
# [ИНФО][QUEUES] регистрируем очередь planner.mqtt
# [ИНФО][QUEUES] регистрируем очередь sitl.mqtt
# [ИНФО][QUEUES] регистрируем очередь planner
# [ИНФО][MISSION PLANNER] создана система планирования заданий
# [ИНФО][QUEUES] регистрируем очередь sitl
# [ИНФО][QUEUES] регистрируем очередь servos
# [ИНФО][QUEUES] регистрируем очередь cargo
# [ИНФО][CARGO] создан компонент грузового отсека, отсек заблокирован
# [ИНФО][QUEUES] регистрируем очередь safety
# [ИНФО][SAFETY] создан ограничитель
# [ИНФО][MISSION PLANNER] старт системы планирования заданий
# [ИНФО][CARGO] старт блока грузового отсека
# [ИНФО][CONTROL] старт системы управления
# [ИНФО][SAFETY] старт ограничителя
# [ИНФО][MISSION PLANNER] запрошена новая задача, отправляем получателям
# [ИНФО][MISSION PLANNER] новая задача отправлена в коммуникационный шлюз
# [ИНФО][CONTROL] установлена новая задача, начинаем следовать по маршруту, текущее время 02:21:53.330755
# [ИНФО][SAFETY] Блокировка грузового отсека
# [ИНФО][CONTROL] новая скорость 20 (была 0)
# [ИНФО][CONTROL] новое направление 294 (было 0)
# [ИНФО][CARGO] заблокировать грузовой отсек
# [ИНФО][CARGO] грузовой отсек заблокирован
# [ИНФО][SAFETY] текущие координаты: 59 52m 53.4688s N, 29 49m 48.1732s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 53.4688s N, 29 49m 48.1732s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 53.4688s N, 29 49m 48.1732s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 53.4688s N, 29 49m 48.1732s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 53.4981s N, 29 49m 48.0428s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 53.5348s N, 29 49m 47.8798s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 53.5715s N, 29 49m 47.7168s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 53.6082s N, 29 49m 47.5539s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 53.6449s N, 29 49m 47.3909s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 53.6815s N, 29 49m 47.2279s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 53.7182s N, 29 49m 47.0649s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 53.7549s N, 29 49m 46.9019s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 53.7916s N, 29 49m 46.739s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 53.8283s N, 29 49m 46.576s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 53.8649s N, 29 49m 46.413s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 53.9016s N, 29 49m 46.25s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 53.9383s N, 29 49m 46.087s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 53.975s N, 29 49m 45.924s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.0116s N, 29 49m 45.761s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.0483s N, 29 49m 45.598s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.085s N, 29 49m 45.435s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.1216s N, 29 49m 45.272s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.1583s N, 29 49m 45.109s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.1949s N, 29 49m 44.946s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.2316s N, 29 49m 44.783s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.2682s N, 29 49m 44.62s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.3049s N, 29 49m 44.457s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.3415s N, 29 49m 44.294s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.3782s N, 29 49m 44.131s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.4148s N, 29 49m 43.9679s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.4514s N, 29 49m 43.8049s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.4881s N, 29 49m 43.6419s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.5247s N, 29 49m 43.4788s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.5613s N, 29 49m 43.3158s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.5979s N, 29 49m 43.1528s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.6345s N, 29 49m 42.9897s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.6711s N, 29 49m 42.8267s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.7077s N, 29 49m 42.6636s E
# [ИНФО][CONTROL] новое направление 293 (было 294)
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.7443s N, 29 49m 42.5005s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.7809s N, 29 49m 42.3374s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.8174s N, 29 49m 42.1744s E
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новое направление 73 (было 293)
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.854s N, 29 49m 42.0112s E
# [ИНФО][CONTROL] новое направление 70 (было 73)
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.8905s N, 29 49m 41.8481s E
# [ИНФО][CONTROL] новое направление 66 (было 70)
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.9269s N, 29 49m 41.6849s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.8938s N, 29 49m 41.5189s E
# [ИНФО][CONTROL] новое направление 67 (было 66)
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.8564s N, 29 49m 41.3566s E
# [ИНФО][CONTROL] новое направление 68 (было 67)
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.8142s N, 29 49m 41.199s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.7721s N, 29 49m 41.0413s E
# [ИНФО][CONTROL] новое направление 69 (было 68)
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.7298s N, 29 49m 40.8838s E
# [ИНФО][CONTROL] новое направление 70 (было 69)
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.6877s N, 29 49m 40.7261s E
# [ИНФО][CONTROL] новое направление 72 (было 70)
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.6474s N, 29 49m 40.5665s E
# [ИНФО][CONTROL] новое направление 74 (было 72)
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.6084s N, 29 49m 40.4056s E
# [ИНФО][CONTROL] новое направление 77 (было 74)
# [ИНФО][CONTROL] новое направление 82 (было 77)
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.5713s N, 29 49m 40.2431s E
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новая скорость 120 (была 20)
# [ИНФО][CONTROL] новое направление 286 (было 82)
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.5363s N, 29 49m 40.0786s E
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][CONTROL] новое направление 292 (было 286)
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.5013s N, 29 49m 39.9141s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.4693s N, 29 49m 39.7473s E
# [ИНФО][CONTROL] новое направление 298 (было 292)
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.4419s N, 29 49m 39.5773s E
# [ИНФО][CONTROL] новое направление 306 (было 298)
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.4227s N, 29 49m 39.4029s E
# [ИНФО][CONTROL] новое направление 309 (было 306)
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.4566s N, 29 49m 39.2376s E
# [ИНФО][CONTROL] новое направление 312 (было 309)
# [ИНФО][CONTROL] новое направление 315 (было 312)
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.4996s N, 29 49m 39.0808s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.5525s N, 29 49m 38.9365s E
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новая скорость 50 (была 120)
# [ИНФО][CONTROL] новое направление 205 (было 315)
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][CONTROL] новое направление 203 (было 205)
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.6094s N, 29 49m 38.7985s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.6664s N, 29 49m 38.6605s E
# [ИНФО][CONTROL] новое направление 201 (было 203)
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.7274s N, 29 49m 38.5295s E
# [ИНФО][CONTROL] новое направление 200 (было 201)
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.792s N, 29 49m 38.4054s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.6274s N, 29 49m 38.2629s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.4192s N, 29 49m 38.0962s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 54.2088s N, 29 49m 37.9407s E
# [ИНФО][CONTROL] новое направление 199 (было 200)
# [ИНФО][SAFETY] текущие координаты: 59 52m 53.9982s N, 29 49m 37.7866s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 53.7876s N, 29 49m 37.6324s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 53.5768s N, 29 49m 37.4794s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 53.366s N, 29 49m 37.3265s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 53.1551s N, 29 49m 37.1738s E
# [ИНФО][CONTROL] новое направление 200 (было 199)
# [ИНФО][SAFETY] текущие координаты: 59 52m 52.9443s N, 29 49m 37.0212s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 52.7334s N, 29 49m 36.8686s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 52.5225s N, 29 49m 36.716s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 52.3117s N, 29 49m 36.5633s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 52.1008s N, 29 49m 36.4106s E
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новое направление 204 (было 200)
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] текущие координаты: 59 52m 51.8899s N, 29 49m 36.2579s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 51.6792s N, 29 49m 36.1047s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 51.4685s N, 29 49m 35.9507s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 51.2645s N, 29 49m 35.7651s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 51.0607s N, 29 49m 35.5781s E
# [ИНФО][CONTROL] новое направление 205 (было 204)
# [ИНФО][SAFETY] текущие координаты: 59 52m 50.8573s N, 29 49m 35.3897s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 50.6538s N, 29 49m 35.2013s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 50.4504s N, 29 49m 35.0127s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 50.2471s N, 29 49m 34.8241s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 50.0437s N, 29 49m 34.6355s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 49.8403s N, 29 49m 34.4468s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 49.637s N, 29 49m 34.2581s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 49.4336s N, 29 49m 34.0693s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 49.2302s N, 29 49m 33.8806s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 49.0269s N, 29 49m 33.6918s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 48.8235s N, 29 49m 33.5031s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 48.6202s N, 29 49m 33.3143s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 48.4169s N, 29 49m 33.1254s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 48.2136s N, 29 49m 32.9366s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 48.0102s N, 29 49m 32.7476s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 47.8069s N, 29 49m 32.5587s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 47.6036s N, 29 49m 32.3697s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 47.4003s N, 29 49m 32.1807s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 47.1971s N, 29 49m 31.9916s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 46.9938s N, 29 49m 31.8024s E
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новое направление 203 (было 205)
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] текущие координаты: 59 52m 46.7906s N, 29 49m 31.613s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 46.5875s N, 29 49m 31.4233s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 46.3846s N, 29 49m 31.2329s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 46.1816s N, 29 49m 31.0425s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 45.9762s N, 29 49m 30.8626s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 45.7707s N, 29 49m 30.6833s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 45.5649s N, 29 49m 30.5053s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 45.3591s N, 29 49m 30.3274s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 45.1533s N, 29 49m 30.1497s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 44.9475s N, 29 49m 29.9719s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 44.7416s N, 29 49m 29.7941s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 44.5358s N, 29 49m 29.6163s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 44.33s N, 29 49m 29.4385s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 44.1241s N, 29 49m 29.2607s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 43.9183s N, 29 49m 29.0827s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 43.7125s N, 29 49m 28.9048s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 43.5068s N, 29 49m 28.7267s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 43.301s N, 29 49m 28.5486s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 43.0952s N, 29 49m 28.3705s E
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новая скорость 20 (была 50)
# [ИНФО][CONTROL] новое направление 204 (было 203)
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] текущие координаты: 59 52m 42.8895s N, 29 49m 28.1923s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 42.6838s N, 29 49m 28.014s E
# [ИНФО][CONTROL] новое направление 205 (было 204)
# [ИНФО][SAFETY] текущие координаты: 59 52m 42.4783s N, 29 49m 27.8346s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 42.3968s N, 29 49m 27.76s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 42.3153s N, 29 49m 27.685s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 42.2341s N, 29 49m 27.6092s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 42.1528s N, 29 49m 27.5334s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 42.0878s N, 29 49m 27.4726s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 42.0066s N, 29 49m 27.3966s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 41.9254s N, 29 49m 27.3205s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 41.8442s N, 29 49m 27.2444s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 41.763s N, 29 49m 27.1682s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 41.6818s N, 29 49m 27.092s E
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новое направление 190 (было 205)
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] текущие координаты: 59 52m 41.6006s N, 29 49m 27.0158s E
# [ИНФО][CONTROL] новое направление 186 (было 190)
# [ИНФО][SAFETY] текущие координаты: 59 52m 41.5195s N, 29 49m 26.9396s E
# [ИНФО][CONTROL] новое направление 181 (было 186)
# [ИНФО][SAFETY] текущие координаты: 59 52m 41.4383s N, 29 49m 26.8632s E
# [ИНФО][CONTROL] новое направление 176 (было 181)
# [ИНФО][SAFETY] текущие координаты: 59 52m 41.3501s N, 29 49m 26.8306s E
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новая скорость 40 (была 20)
# [ИНФО][CONTROL] новое направление 139 (было 176)
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] текущие координаты: 59 52m 41.261s N, 29 49m 26.809s E
# [ИНФО][CONTROL] новое направление 131 (было 139)
# [ИНФО][SAFETY] текущие координаты: 59 52m 41.1713s N, 29 49m 26.8057s E
# [ИНФО][CONTROL] новое направление 121 (было 131)
# [ИНФО][CONTROL] новое направление 105 (было 121)
# [ИНФО][SAFETY] текущие координаты: 59 52m 41.0817s N, 29 49m 26.8163s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 40.9443s N, 29 49m 27.0463s E
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новая скорость 20 (была 40)
# [ИНФО][CONTROL] новое направление 112 (было 105)
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] текущие координаты: 59 52m 40.807s N, 29 49m 27.2763s E
# [ИНФО][CONTROL] новое направление 111 (было 112)
# [ИНФО][SAFETY] текущие координаты: 59 52m 40.6872s N, 29 49m 27.5423s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 40.6384s N, 29 49m 27.8859s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 40.6043s N, 29 49m 28.051s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 40.5712s N, 29 49m 28.217s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 40.5377s N, 29 49m 28.3827s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 40.5043s N, 29 49m 28.5484s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 40.4709s N, 29 49m 28.7141s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 40.4374s N, 29 49m 28.8798s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 40.404s N, 29 49m 29.0455s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 40.3706s N, 29 49m 29.2112s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 40.3371s N, 29 49m 29.3769s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 40.3037s N, 29 49m 29.5427s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 40.2703s N, 29 49m 29.7084s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 40.2368s N, 29 49m 29.8741s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 40.2034s N, 29 49m 30.0398s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 40.17s N, 29 49m 30.2055s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 40.1366s N, 29 49m 30.3712s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 40.1031s N, 29 49m 30.5369s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 40.0697s N, 29 49m 30.7026s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 40.0363s N, 29 49m 30.8683s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 40.0029s N, 29 49m 31.0341s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.9695s N, 29 49m 31.1998s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.9361s N, 29 49m 31.3655s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.9026s N, 29 49m 31.5312s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.8692s N, 29 49m 31.6969s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.8358s N, 29 49m 31.8627s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.8024s N, 29 49m 32.0284s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.769s N, 29 49m 32.1941s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.7356s N, 29 49m 32.3598s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.7022s N, 29 49m 32.5256s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.6688s N, 29 49m 32.6913s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.6354s N, 29 49m 32.857s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.602s N, 29 49m 33.0228s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.5686s N, 29 49m 33.1885s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.5352s N, 29 49m 33.3542s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.5018s N, 29 49m 33.52s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.4684s N, 29 49m 33.6857s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.435s N, 29 49m 33.8515s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.4017s N, 29 49m 34.0172s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.3683s N, 29 49m 34.1829s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.3349s N, 29 49m 34.3487s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.3015s N, 29 49m 34.5145s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.2682s N, 29 49m 34.6802s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.2348s N, 29 49m 34.846s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.2015s N, 29 49m 35.0117s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.1681s N, 29 49m 35.1775s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.1348s N, 29 49m 35.3433s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.1014s N, 29 49m 35.5091s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.0681s N, 29 49m 35.6749s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.0348s N, 29 49m 35.8407s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 39.0015s N, 29 49m 36.0065s E
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новое направление 115 (было 111)
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.9748s N, 29 49m 36.1391s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.9416s N, 29 49m 36.3049s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.9084s N, 29 49m 36.4708s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.8701s N, 29 49m 36.6323s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.8318s N, 29 49m 36.7938s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.7933s N, 29 49m 36.9551s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.7549s N, 29 49m 37.1165s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.7165s N, 29 49m 37.2778s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.678s N, 29 49m 37.4392s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.6396s N, 29 49m 37.6005s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.6011s N, 29 49m 37.7619s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.5627s N, 29 49m 37.9232s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.5243s N, 29 49m 38.0846s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.4858s N, 29 49m 38.246s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.4474s N, 29 49m 38.4073s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.409s N, 29 49m 38.5687s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.3705s N, 29 49m 38.73s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.3321s N, 29 49m 38.8914s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.2937s N, 29 49m 39.0527s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.2553s N, 29 49m 39.2141s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.2168s N, 29 49m 39.3755s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.1784s N, 29 49m 39.5368s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.14s N, 29 49m 39.6982s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.1016s N, 29 49m 39.8596s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.0632s N, 29 49m 40.0209s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 38.0247s N, 29 49m 40.1823s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.9863s N, 29 49m 40.3437s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.9479s N, 29 49m 40.5051s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.9095s N, 29 49m 40.6664s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.8711s N, 29 49m 40.8278s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.8327s N, 29 49m 40.9892s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.7943s N, 29 49m 41.1506s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.7559s N, 29 49m 41.3119s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.7175s N, 29 49m 41.4733s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.6791s N, 29 49m 41.6347s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.6407s N, 29 49m 41.7961s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.6023s N, 29 49m 41.9575s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.5639s N, 29 49m 42.1189s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.5255s N, 29 49m 42.2803s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.4871s N, 29 49m 42.4417s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.4488s N, 29 49m 42.6031s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.4104s N, 29 49m 42.7645s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.372s N, 29 49m 42.9259s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.3336s N, 29 49m 43.0873s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.2953s N, 29 49m 43.2487s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.2569s N, 29 49m 43.4102s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.2186s N, 29 49m 43.5716s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.1802s N, 29 49m 43.733s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.1419s N, 29 49m 43.8945s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.1036s N, 29 49m 44.0559s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.0652s N, 29 49m 44.2174s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 37.0269s N, 29 49m 44.3788s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 36.9886s N, 29 49m 44.5403s E
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новое направление 161 (было 115)
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] текущие координаты: 59 52m 36.9503s N, 29 49m 44.7018s E
# [ИНФО][CONTROL] новое направление 176 (было 161)
# [ИНФО][SAFETY] текущие координаты: 59 52m 36.912s N, 29 49m 44.8633s E
# [ИНФО][CONTROL] новое направление 197 (было 176)
# [ИНФО][SAFETY] текущие координаты: 59 52m 36.8738s N, 29 49m 45.0249s E
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новое направление 208 (было 197)
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] текущие координаты: 59 52m 36.7886s N, 29 49m 45.0809s E
# [ИНФО][CONTROL] новое направление 210 (было 208)
# [ИНФО][CONTROL] новое направление 211 (было 210)
# [ИНФО][SAFETY] текущие координаты: 59 52m 36.699s N, 29 49m 45.0905s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 36.6136s N, 29 49m 45.0356s E
# [ИНФО][CONTROL] новое направление 212 (было 211)
# [ИНФО][SAFETY] текущие координаты: 59 52m 36.5282s N, 29 49m 44.9807s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 36.4493s N, 29 49m 44.8956s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 36.3726s N, 29 49m 44.8026s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 36.2968s N, 29 49m 44.707s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 36.2213s N, 29 49m 44.6104s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 36.1459s N, 29 49m 44.5136s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 36.0856s N, 29 49m 44.436s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 36.0103s N, 29 49m 44.339s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 35.9349s N, 29 49m 44.242s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 35.8596s N, 29 49m 44.1449s E
# [ИНФО][CONTROL] новое направление 213 (было 212)
# [ИНФО][SAFETY] текущие координаты: 59 52m 35.7843s N, 29 49m 44.0478s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 35.709s N, 29 49m 43.9506s E
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новое направление 203 (было 213)
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] текущие координаты: 59 52m 35.6337s N, 29 49m 43.8534s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 35.5584s N, 29 49m 43.7561s E[ИНФО][CONTROL] новое направление 202 (было 203)
#
# [ИНФО][SAFETY] текущие координаты: 59 52m 35.4832s N, 29 49m 43.6587s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 35.408s N, 29 49m 43.5613s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 35.326s N, 29 49m 43.4887s E
# [ИНФО][CONTROL] новое направление 201 (было 202)
# [ИНФО][SAFETY] текущие координаты: 59 52m 35.2436s N, 29 49m 43.4177s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 35.1605s N, 29 49m 43.3502s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 35.0773s N, 29 49m 43.2832s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 34.9941s N, 29 49m 43.2164s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 34.9108s N, 29 49m 43.1496s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 34.8276s N, 29 49m 43.0829s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 34.7443s N, 29 49m 43.0161s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 34.6611s N, 29 49m 42.9494s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 34.5778s N, 29 49m 42.8827s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 34.4946s N, 29 49m 42.8159s E
# [ИНФО][CONTROL] новое направление 202 (было 201)
# [ИНФО][SAFETY] текущие координаты: 59 52m 34.4113s N, 29 49m 42.7491s E
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новое направление 224 (было 202)
# [ИНФО][SAFETY] текущие координаты: 59 52m 34.3281s N, 29 49m 42.6823s E
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] текущие координаты: 59 52m 34.2449s N, 29 49m 42.6155s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 34.1616s N, 29 49m 42.5487s E
# [ИНФО][CONTROL] новое направление 225 (было 224)
# [ИНФО][SAFETY] текущие координаты: 59 52m 34.0784s N, 29 49m 42.4818s E
# [ИНФО][CONTROL] новое направление 226 (было 225)
# [ИНФО][SAFETY] текущие координаты: 59 52m 33.9952s N, 29 49m 42.4148s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 33.9316s N, 29 49m 42.2887s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 33.869s N, 29 49m 42.1609s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 33.8073s N, 29 49m 42.0312s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 33.7457s N, 29 49m 41.9013s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 33.6841s N, 29 49m 41.7715s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 33.6225s N, 29 49m 41.6415s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 33.561s N, 29 49m 41.5116s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 33.4994s N, 29 49m 41.3816s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 33.4379s N, 29 49m 41.2516s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 33.3764s N, 29 49m 41.1217s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 33.3148s N, 29 49m 40.9917s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 33.2533s N, 29 49m 40.8617s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 33.1918s N, 29 49m 40.7317s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 33.1303s N, 29 49m 40.6017s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 33.0687s N, 29 49m 40.4717s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 33.0072s N, 29 49m 40.3416s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 32.9457s N, 29 49m 40.2116s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 32.8842s N, 29 49m 40.0816s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 32.8227s N, 29 49m 39.9515s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 32.7612s N, 29 49m 39.8214s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 32.6997s N, 29 49m 39.6914s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 32.6383s N, 29 49m 39.5613s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 32.5768s N, 29 49m 39.4312s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 32.5154s N, 29 49m 39.301s E
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новое направление 167 (было 226)
# [ИНФО][CONTROL] новое направление 164 (было 167)
# [ИНФО][SAFETY] текущие координаты: 59 52m 32.4539s N, 29 49m 39.1708s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 32.3925s N, 29 49m 39.0406s E
# [ИНФО][CONTROL] новое направление 161 (было 164)
# [ИНФО][SAFETY] текущие координаты: 59 52m 32.3311s N, 29 49m 38.9104s E
# [ИНФО][CONTROL] новое направление 157 (было 161)
# [ИНФО][SAFETY] текущие координаты: 59 52m 32.2698s N, 29 49m 38.7801s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 32.1833s N, 29 49m 38.8279s E
# [ИНФО][CONTROL] новое направление 156 (было 157)
# [ИНФО][SAFETY] текущие координаты: 59 52m 32.0984s N, 29 49m 38.8857s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 32.0154s N, 29 49m 38.9538s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 31.9327s N, 29 49m 39.0233s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 31.8502s N, 29 49m 39.0938s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 31.7678s N, 29 49m 39.1642s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 31.6853s N, 29 49m 39.2349s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 31.6029s N, 29 49m 39.3057s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 31.5206s N, 29 49m 39.3765s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 31.4382s N, 29 49m 39.4474s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 31.3558s N, 29 49m 39.5184s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 31.2734s N, 29 49m 39.5894s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 31.2076s N, 29 49m 39.6462s E
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новое направление 199 (было 156)
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] текущие координаты: 59 52m 31.1252s N, 29 49m 39.7172s E
# [ИНФО][CONTROL] новое направление 208 (было 199)
# [ИНФО][SAFETY] текущие координаты: 59 52m 31.0429s N, 29 49m 39.7882s E
# [ИНФО][CONTROL] новое направление 220 (было 208)
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.9606s N, 29 49m 39.8594s E
# [ИНФО][CONTROL] новое направление 227 (было 220)
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.8762s N, 29 49m 39.7986s E
# [ИНФО][CONTROL] новое направление 236 (было 227)
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.7975s N, 29 49m 39.7125s E
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новое направление 146 (было 236)
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.7293s N, 29 49m 39.5965s E
# [ИНФО][CONTROL] новое направление 138 (было 146)
# [ИНФО][CONTROL] новое направление 131 (было 138)
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.6684s N, 29 49m 39.4654s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.6074s N, 29 49m 39.3343s E
# [ИНФО][CONTROL] новое направление 124 (было 131)
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.5573s N, 29 49m 39.1863s E
# [ИНФО][CONTROL] новое направление 121 (было 124)
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.4828s N, 29 49m 39.2859s E
# [ИНФО][CONTROL] новое направление 119 (было 121)
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.4236s N, 29 49m 39.4202s E
# [ИНФО][CONTROL] новое направление 118 (было 119)
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.373s N, 29 49m 39.5676s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.3263s N, 29 49m 39.7201s E
# [ИНФО][CONTROL] новое направление 117 (было 118)
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.2818s N, 29 49m 39.8752s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.2386s N, 29 49m 40.0316s E
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новое направление 73 (было 117)
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.1953s N, 29 49m 40.1881s E
# [ИНФО][CONTROL] новое направление 70 (было 73)
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.1529s N, 29 49m 40.3454s E
# [ИНФО][CONTROL] новое направление 67 (было 70)
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.112s N, 29 49m 40.5043s E
# [ИНФО][CONTROL] новое направление 66 (было 67)
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.137s N, 29 49m 40.6758s E
# [ИНФО][CONTROL] новое направление 65 (было 66)
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.1668s N, 29 49m 40.8442s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.2018s N, 29 49m 41.0085s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.2378s N, 29 49m 41.1721s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.2738s N, 29 49m 41.3357s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.3104s N, 29 49m 41.4987s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.3471s N, 29 49m 41.6616s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.3841s N, 29 49m 41.8243s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.4212s N, 29 49m 41.9869s E
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новое направление 88 (было 65)
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.4583s N, 29 49m 42.1495s E
# [ИНФО][CONTROL] новое направление 90 (было 88)
# [ИНФО][CONTROL] новое направление 93 (было 90)
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.4954s N, 29 49m 42.312s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.5325s N, 29 49m 42.4746s E
# [ИНФО][CONTROL] новое направление 96 (было 93)
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.5696s N, 29 49m 42.6372s E
# [ИНФО][CONTROL] новое направление 97 (было 96)
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.5715s N, 29 49m 42.8157s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.5663s N, 29 49m 42.9939s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.5567s N, 29 49m 43.1714s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.5456s N, 29 49m 43.3486s E
# [ИНФО][CONTROL] новое направление 98 (было 97)
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.5337s N, 29 49m 43.5255s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.5215s N, 29 49m 43.7024s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.5092s N, 29 49m 43.8793s E
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новое направление 114 (было 98)
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.4967s N, 29 49m 44.0561s E
# [ИНФО][CONTROL] новое направление 115 (было 114)
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.4842s N, 29 49m 44.2329s E
# [ИНФО][CONTROL] новое направление 116 (было 115)
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.4713s N, 29 49m 44.4096s E
# [ИНФО][CONTROL] новое направление 117 (было 116)
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.4344s N, 29 49m 44.5724s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.3958s N, 29 49m 44.7336s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.3553s N, 29 49m 44.8929s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.3148s N, 29 49m 45.0522s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.274s N, 29 49m 45.2112s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.2329s N, 29 49m 45.3699s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.1917s N, 29 49m 45.5286s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.1505s N, 29 49m 45.6872s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.1093s N, 29 49m 45.8458s E
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новое направление 142 (было 117)
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.0681s N, 29 49m 46.0044s E
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][CONTROL] новое направление 144 (было 142)
# [ИНФО][SAFETY] текущие координаты: 59 52m 30.0269s N, 29 49m 46.163s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 29.9857s N, 29 49m 46.3216s E
# [ИНФО][CONTROL] новое направление 147 (было 144)
# [ИНФО][SAFETY] текущие координаты: 59 52m 29.9445s N, 29 49m 46.4802s E
# [ИНФО][CONTROL] новое направление 150 (было 147)
# [ИНФО][SAFETY] текущие координаты: 59 52m 29.9033s N, 29 49m 46.6389s E
# [ИНФО][CONTROL] новое направление 151 (было 150)
# [ИНФО][SAFETY] текущие координаты: 59 52m 29.83s N, 29 49m 46.7418s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 29.7544s N, 29 49m 46.8381s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 29.6763s N, 29 49m 46.9263s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 29.5978s N, 29 49m 47.0128s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 29.5193s N, 29 49m 47.0993s E
# [ИНФО][CONTROL] новое направление 152 (было 151)
# [ИНФО][SAFETY] текущие координаты: 59 52m 29.4404s N, 29 49m 47.1845s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 29.3614s N, 29 49m 47.2692s E
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новое направление 166 (было 152)
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] текущие координаты: 59 52m 29.2822s N, 29 49m 47.3531s E
# [ИНФО][CONTROL] новое направление 167 (было 166)
# [ИНФО][SAFETY] текущие координаты: 59 52m 29.2029s N, 29 49m 47.4368s E
# [ИНФО][CONTROL] новое направление 168 (было 167)
# [ИНФО][CONTROL] новое направление 169 (было 168)
# [ИНФО][SAFETY] текущие координаты: 59 52m 29.1235s N, 29 49m 47.5201s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 29.0536s N, 29 49m 47.553s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 28.9659s N, 29 49m 47.591s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 28.8782s N, 29 49m 47.6289s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 28.7901s N, 29 49m 47.663s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 28.7019s N, 29 49m 47.6967s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 28.6137s N, 29 49m 47.7294s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 28.5255s N, 29 49m 47.762s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 28.4372s N, 29 49m 47.7945s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 28.3489s N, 29 49m 47.8269s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 28.2607s N, 29 49m 47.8594s E
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новое направление 190 (было 169)
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] текущие координаты: 59 52m 28.1724s N, 29 49m 47.8918s E
# [ИНФО][CONTROL] новое направление 192 (было 190)
# [ИНФО][SAFETY] текущие координаты: 59 52m 28.0841s N, 29 49m 47.9242s E
# [ИНФО][CONTROL] новое направление 195 (было 192)
# [ИНФО][SAFETY] текущие координаты: 59 52m 27.9959s N, 29 49m 47.9566s E
# [ИНФО][CONTROL] новое направление 196 (было 195)
# [ИНФО][SAFETY] текущие координаты: 59 52m 27.9076s N, 29 49m 47.9243s E
# [ИНФО][CONTROL] новое направление 197 (было 196)
# [ИНФО][SAFETY] текущие координаты: 59 52m 27.8201s N, 29 49m 47.8845s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 27.7338s N, 29 49m 47.8354s E
# [ИНФО][CONTROL] новое направление 198 (было 197)
# [ИНФО][CONTROL] новое направление 199 (было 198)
# [ИНФО][SAFETY] текущие координаты: 59 52m 27.6475s N, 29 49m 47.7862s E
# [ИНФО][SAFETY] текущие координаты: 59 52m 27.5616s N, 29 49m 47.7345s E
# [ИНФО][CONTROL] маршрут пройден, текущее время 02:25:28.680709
# [ИНФО][CONTROL] новая скорость 0.0 (была 20)
# [ИНФО][CONTROL] новое направление 0 (было 199)
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] текущие координаты: 59 52m 27.4762s N, 29 49m 47.6795s E
# [ОШИБКА][SAFETY] ошибка обработки команд: 'NoneType' object has no attribute 'longitude'
# [ИНФО][CARGO] выгрузка
# [ИНФО][CARGO] груз оставлен
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден

# %% [markdown]
# #### Обеспечение ЦБ3: контроль доставки груза
#
# С помощью логики ограничителя выше мы реализовали обеспечение ЦБ1 (соблюдение заданных ограничений), однако есть ещё ЦБ3 (отгрузка только в заданной точке), не говоря о ЦБ2 (следование только по аутентичному маршруту).
#
# Для обеспечения ЦБ3 необходимо сделать следующее
# 1. изменить последовательность передачи команд, чтобы в блок управления грузовым отсеком (CargoBay) команды приходили только после проверки в Ограничителе
# 2. доработайте реализацию Ограничителя, чтобы команда на выгрузку передавалась в CargoBay только в конечной точке маршрута
# 3. продумайте логику работы блока безопасности, если система управления полностью перестанет работать (т.е. перестанет отправлять новые команды).
#
# Изменённая архитектура приведена на рис. 7.
#
# ![Ограничитель для обеспечения ЦБ1 и ЦБ3](images/ciac-arch-m312.png)
#
# Рис. 7. Ограничитель для обеспечения ЦБ1 и ЦБ3

# %%
# напишите свой код в этой ячейке, запустите машинку по маршруту, убедитесь, 
# что в конечной (и только в конечной!) точке CargoBay получает команду и успешно выполняет выгрузку

# %% [markdown]
# #### *Опциональное задание повышенной сложности* Обеспечение ЦБ2
#
# **Перед началом работы над этой задачей рекомендуем сохранить все текущие изменения в git репозитории (git commit, git push).**
#
# Напомним цель безопасности №2 (ЦБ2): "При любых обстоятельствах АНТС выполняет только аутентичный (подлинный) маршрут"
#
# Обеспечение ЦБ2 потребует
# - внедрения механизма **контроля аутентичности маршрутного задания** (mission), а значит
# - помимо изменения **блока безопасности** (SafetyBlock), модификации
#   - системы **планирования задания** (MissionPlanner)
#   - **коммуникационного шлюза** (CommunicationGateway)
#   - и, возможно, **системы управления** (ControlSystem).
#
# Для решения этой задачи допустимо менять код соответствующих модулей в папке src.
#
# Возможным решением является внедрение механизма цифровой подписи, верификацией которой будет заниматься блок безопасности. В этой ситуации если коммуникационный шлюз (блок "1. Связь" на рис. 5 в модуле 1) оказался скомпрометированным и изменил маршрутное задание, оно не должно пройти проверку подлинности в блоке безопасности.
#
# **Рекомендуем эту задачу делать в последнюю очередь**, *после успешного выполнения модуля 4*, поскольку успешное выполнение модуля 4 принесёт больше баллов, чем внедрение цифровой подписи и обеспечение ЦБ2.
# К сведению, реализованные в этой версии киберпрепятствия не предполагают компрометацию маршрутного задания.
#
# Конечно, если будут решены все основные задачи и к тому же обеспечен контроль аутентичности маршрутного задания, такая работа с высокой вероятностью окажется лучшей.

# %%
# если вы собираетесь выполнить это задание, напишите в этой ячейке код выполнения изменённых блоков. 
# cам код допускается редактировать в папке src
# в случае успешной реализации машинка должна успешно пройти по маршруту, а в случае искажения маршрутного задания в блоке коммуникационного шлюза должна остаться на месте, 
# при этом именно блок безопасности должен заблокировать движение

# %% [markdown]
# ### Задание 3.2. Монитор безопасности

# %% [markdown]
# В текущей реализации каждый блок сам решает куда и какие данные ему отправлять. Это приемлемо, когда каждый блок рассматривается как благонадёжный. Однако нельзя исключать ситуацию успешной компрометации какого-либо из блоков (одного или нескольких), в результате которой злоумышленник может получить полный контроль над частью системы.
#
# В такой ситуации необходимо выстроить внутреннюю "поверхность защиты", частью этой системы уже является блок "Ограничитель", однако необходимо сделать так, чтобы соответствующие запросы проходили только через него, а не в обход.
#
# Для решения этой задачи необходимо добавить новый блок "Монитор безопасности". Его задача - обеспечить контроль направления информационных потоков, допустить передачу данных только между теми блоками и в тех направлениях, которые задуманы архитектором системы. Тогда, например, попытка передать команду из системы управления напрямую в сервоприводы в обход ограничителя будет заблокирована.
#
# Возможно, возникнет вопрос, а что помешает злоумышленнику отправить команду в обход этого монитора безопасности. В рамках этой учебной инфраструктуры особо ничего, однако при разработке реальной системы можно использовать специализированные микроядерные операционные системы, такие как, например, KasperskyOS, которые обеспечат обязательное вовлечение монитора безопасности в контроль взаимодействия между блоками.
#
# Архитектура системы для решения задачи 3.2 должна выглядеть как на рис.8:
#
# ![Архитектура системы с монитором безопасности](images/ciac-arch-m32.png)
#
# Рис. 8. Архитектура бортовых систем с монитором безопасности

# %% [markdown]
# Базовый класс модуля безопасности находится в файле src/security_monitor.py, его менять не нужно.
#
# В следующей ячейке находится реализация класса SecurityMonitor

# %%
from src.security_monitory import BaseSecurityMonitor
from src.security_policy_type import SecurityPolicy
from src.crypto_module import verify_signature
from src.config import COMMUNICATION_GATEWAY_QUEUE_NAME, LOG_DEBUG, LOG_ERROR, LOG_INFO
    
    
class SecurityMonitor(BaseSecurityMonitor):
    """ класс монитора безопасности """

    def __init__(self, queues_dir):
        super().__init__(queues_dir)
        self._init_set_security_policies()

    def _init_set_security_policies(self):
        """ инициализация политик безопасности """
        default_policies = [
            SecurityPolicy(
                source=COMMUNICATION_GATEWAY_QUEUE_NAME,
                destination=CONTROL_SYSTEM_QUEUE_NAME,
                operation='set_mission')
        ]
        self.set_security_policies(policies=default_policies)        

    def set_security_policies(self, policies):
        """ установка новых политик безопасности """
        self._security_policies = policies
        self._log_message(
            LOG_INFO, f"изменение политик безопасности: {policies}")

    def _check_event(self, event: Event):
        """ проверка входящих событий """
        self._log_message(
            LOG_DEBUG, f"проверка события {event}, по умолчанию выполнение запрещено")

        authorized = False
        request = SecurityPolicy(
            source=event.source,
            destination=event.destination,
            operation=event.operation)

        if request in self._security_policies:
            self._log_message(
                LOG_DEBUG, "событие разрешено политиками, выполняем")
            authorized = True

        if not verify_signature(tuple(event.source, event.destination, event.operation, event.parameters), event.signature, self.public_key):
            self._log_message(LOG_ERROR, f"событие не прошло проверку цифровой подписи! {event}")
            authorized = False

        if authorized is False:
            self._log_message(LOG_ERROR, f"событие не разрешено политиками безопасности! {event}")
        return authorized

# %% [markdown]
# Обратите внимание на этот код:
# ```python
#     def _init_set_security_policies(self):
#         """ инициализация политик безопасности """
#         default_policies = [
#             SecurityPolicy(
#                 source=COMMUNICATION_GATEWAY_QUEUE_NAME,
#                 destination=CONTROL_SYSTEM_QUEUE_NAME,
#                 operation='set_mission')
#         ]
#         self.set_security_policies(policies=default_policies)
# ```
#
# В нём инициализируется политика безопасности, разрешающая запрос set_mission от коммуникационного шлюза в систему управления.
#
# Код политики безопасности в строка 6-9:
# ```python
# SecurityPolicy(
#                 source=COMMUNICATION_GATEWAY_QUEUE_NAME,
#                 destination=CONTROL_SYSTEM_QUEUE_NAME,
#                 operation='set_mission')
# ```
#
# Шаблон политики безопасности описан в файле src/security_policy_type.py:
# ```python
# @dataclass
# class SecurityPolicy:
#     """ политика безопасности """
#     source: str         # отправитель запроса
#     destination: str    # получатель
#     operation: str      # запрашиваемая операция
#
# ```
#
# По аналогии в методе _init_set_security_policies допишите другие политики безопасности, чтобы разрешить взаимодействия согласно диаграмме на рис.7. выше.

# %% [markdown]
# Теперь необходимо изменить взаимодействие между блоками так, чтобы оно всегда проходило через монитор безопасности. Для этого потребуется изменить соответствующие реализации внутренних блоков.

# %% [markdown]
# Ниже пример для блока навигации. Обратите внимание на выделенные строки и комментарии.
#
# ```python
# from src.navigation_system import BaseNavigationSystem
# from src.config import CONTROL_SYSTEM_QUEUE_NAME, SECURITY_MONITOR_QUEUE_NAME
#
#
# class NavigationSystem(BaseNavigationSystem):
#     """ класс навигационного блока """
#     def _send_position_to_consumers(self):
#         # событие для системы управления,
#         # поэтому в destination указываем CONTROL_SYSTEM_QUEUE_NAME
#         event = Event(source=self.event_source_name,
# >>>                      destination=CONTROL_SYSTEM_QUEUE_NAME,
#                       operation="position_update", parameters=self._position
#                       )
#         # но событие отправляем сначала на проверку в монитор безопасности,
#         # поэтому используем очередь с именем SECURITY_MONITOR_QUEUE_NAME
# >>>        security_monitor_q: Queue = self._queues_dir.get_queue(SECURITY_MONITOR_QUEUE_NAME)
#         security_monitor_q.put(event)
#         # а в систему управления наше событие монитор безопасности отправит сам, если найдёт разрешающую эту операцию политику безопасности
#
# navigation_system = NavigationSystem(queues_dir=queues_dir)
# ```

# %% [markdown]
# from src.navigation_system import BaseNavigationSystem
# from src.config import CONTROL_SYSTEM_QUEUE_NAME, SECURITY_MONITOR_QUEUE_NAME
#
#
# class NavigationSystem(BaseNavigationSystem):
#     """ класс навигационного блока """
#     def _send_position_to_consumers(self):
#         event = Event(source=self.event_source_name,
#                       destination=CONTROL_SYSTEM_QUEUE_NAME,
#                       operation="position_update", parameters=self._position
#                       )
#         security_monitor_q: Queue = self._queues_dir.get_queue(SECURITY_MONITOR_QUEUE_NAME)
#         security_monitor_q.put(event)
#
# navigation_system = NavigationSystem(queues_dir=queues_dir)

# %% [markdown]
# В файле tests/module/test_security_monitor.py можно увидеть тест логики работы монитора безопасности. Запустить его можно следующей командой:

# %%
# !pytest -svk security_monitor

# %% [markdown]
# В одном кодовом блоке ниже (или нескольких - как будет удобнее)  сделайте следующее
#
# 1. Измените реализацию монитора безопасности в части правил проверки передаваемых сообщений в мониторе безопасности
# 2. Измените параметры отправки сообщений между элементами бортовых систем (блоками 1-7), чтобы они всегда отправлялись в очередь монитора безопасности (отправитель и получатель при этом не меняются)
# 3. После всех изменений убедитесь в том, что машинка по-прежнему успешно выполняет маршрутное задание и доставляет груз
# 4. Дополнительные баллы принесут автоматические тесты правил безопасности в файле tests/module/test_security_monitor.py - можно проверить, что все новые политики работают как ожидаются, а недопустимые взаимодействия (т.е. таких стрелок нет на рис. 8) блокируются

# %%
# добавьте изменения сюда

from src.security_monitory import BaseSecurityMonitor
from src.security_policy_type import SecurityPolicy

from src.config import *
    
    
class SecurityMonitor(BaseSecurityMonitor):
    """ класс монитора безопасности """

    def __init__(self, queues_dir):
        super().__init__(queues_dir)
        self._init_set_security_policies()

    def _init_set_security_policies(self):
        """ инициализация политик безопасности """
        default_policies = [
            SecurityPolicy(
                source=COMMUNICATION_GATEWAY_QUEUE_NAME,
                destination=CONTROL_SYSTEM_QUEUE_NAME,
                operation='set_mission'),
            SecurityPolicy(
                source=COMMUNICATION_GATEWAY_QUEUE_NAME,
                destination=SAFETY_BLOCK_QUEUE_NAME,
                operation="set_mission"),
            SecurityPolicy(
                source=CONTROL_SYSTEM_QUEUE_NAME,
                destination=NAVIGATION_QUEUE_NAME,
                operation="request_position"),
            SecurityPolicy(
                source=NAVIGATION_QUEUE_NAME,
                destination=SAFETY_BLOCK_QUEUE_NAME,
                operation="position_update"),
            SecurityPolicy(
                source=NAVIGATION_QUEUE_NAME,
                destination=CONTROL_SYSTEM_QUEUE_NAME,
                operation="position_update"),
            SecurityPolicy(
                source=CONTROL_SYSTEM_QUEUE_NAME,
                destination=SAFETY_BLOCK_QUEUE_NAME,
                operation="set_speed"),
            SecurityPolicy(
                source=CONTROL_SYSTEM_QUEUE_NAME,
                destination=SAFETY_BLOCK_QUEUE_NAME,
                operation="set_direction"),
            SecurityPolicy(
                source=SAFETY_BLOCK_QUEUE_NAME,
                destination=SERVOS_QUEUE_NAME,
                operation="set_speed"),
            SecurityPolicy(
                source=SAFETY_BLOCK_QUEUE_NAME,
                destination=SERVOS_QUEUE_NAME,
                operation="set_direction"),
            SecurityPolicy(
                source=SAFETY_BLOCK_QUEUE_NAME,
                destination=CARGO_BAY_QUEUE_NAME,
                operation="release_cargo"),
            SecurityPolicy(
                source=SAFETY_BLOCK_QUEUE_NAME,
                destination=CARGO_BAY_QUEUE_NAME,
                operation="lock_cargo")
        ]
        self.set_security_policies(policies=default_policies)        

    def set_security_policies(self, policies):
        """ установка новых политик безопасности """
        self._security_policies = policies
        self._log_message(
            LOG_INFO, f"изменение политик безопасности: {policies}")

    def _check_event(self, event: Event):
        """ проверка входящих событий """
        self._log_message(
            LOG_DEBUG, f"проверка события {event}, по умолчанию выполнение запрещено")

        authorized = False
        request = SecurityPolicy(
            source=event.source,
            destination=event.destination,
            operation=event.operation)

        if request in self._security_policies:
            self._log_message(
                LOG_DEBUG, "событие разрешено политиками, выполняем")
            authorized = True

        if not verify_signature(tuple(event.source, event.destination, event.operation, event.parameters), event.signature, self.public_key):
            self._log_message(LOG_ERROR, f"событие не прошло проверку цифровой подписи! {event}")
            authorized = False
        if authorized is False:
            self._log_message(LOG_ERROR, f"событие не разрешено политиками безопасности! {event}")
        return authorized

# %%
from src.safety_block import BaseSafetyBlock
from src.config import *
import math
from time import sleep
from geopy import Point as GeoPoint
from src.config import LOG_ERROR, LOG_INFO, LOG_DEBUG
from multiprocessing import Queue
from src.config import SERVOS_QUEUE_NAME
from src.event_types import Event


# 2. напишите в этом блоке реализацию изменённых блоков связи, управления и навигации, 
# чтобы передавать данные согласно изменённой архитектуре на рис. 5 для обеспечения работы по сценарию на рис.6

# вставьте сюда ваш код
from src.control_system import BaseControlSystem
from src.navigation_system import BaseNavigationSystem
from src.communication_gateway import BaseCommunicationGateway
from multiprocessing import Queue
from src.config import SAFETY_BLOCK_QUEUE_NAME
from src.config import SERVOS_QUEUE_NAME
from src.config import CONTROL_SYSTEM_QUEUE_NAME
from src.event_types import Event


class ControlSystem(BaseControlSystem):
    """ControlSystem блок расчёта управления """

    def _send_speed_and_direction_to_consumers(self, speed, direction):
        safety_q_name = SAFETY_BLOCK_QUEUE_NAME # замените на правильное название очереди

        # отправка сообщения с желаемой скоростью
        event_speed = Event(source=BaseControlSystem.event_source_name,
                      destination=safety_q_name,
                      operation="set_speed", parameters=speed
                    ) # замените на код создания сообщения со скоростью для приводов
                           # подсказка, требуемая операция - set_speed

        # отправка сообщения с желаемым направлением
        event_direction = Event(source=BaseControlSystem.event_source_name,
                      destination=safety_q_name,
                      operation="set_direction", parameters=direction
                    ) # замените на код создания сообщения с направлением для приводов
                               # подсказка, требуемая операция - set_direction

        security_monitor_q = self._queues_dir.get_queue(SECURITY_MONITOR_QUEUE_NAME)
        security_monitor_q.put(event_direction)
        security_monitor_q.put(event_speed)
        
    def _lock_cargo(self):
        """ заблокировать грузовой отсек """
        event = Event(source=CONTROL_SYSTEM_QUEUE_NAME,
                    destination=SAFETY_BLOCK_QUEUE_NAME,
                    operation="lock_cargo", parameters= None
                    )
        security_monitor_q = self._queues_dir.get_queue(SECURITY_MONITOR_QUEUE_NAME)
        security_monitor_q.put(event)

    def _release_cargo(self):
        """ открыть грузовой отсек """
        event = Event(source=CONTROL_SYSTEM_QUEUE_NAME, 
                    destination=SAFETY_BLOCK_QUEUE_NAME,
                    operation="release_cargo", parameters= None
                    )  
        security_monitor_q = self._queues_dir.get_queue(SECURITY_MONITOR_QUEUE_NAME)
        security_monitor_q.put(event)


class CommunicationGateway(BaseCommunicationGateway):
    """CommunicationGateway класс для реализации логики взаимодействия
    с системой планирования заданий

    Работает в отдельном процессе, поэтому создаётся как наследник класса Process
    """
    def _send_mission_to_consumers(self):
        """ метод для отправки сообщения с маршрутным заданием в систему управления """
        control_q_name = CONTROL_SYSTEM_QUEUE_NAME
        event = Event(source=BaseCommunicationGateway.event_source_name,
                      destination=control_q_name,
                      operation="set_mission", parameters=self._mission
                      )
        security_monitor_q = self._queues_dir.get_queue(SECURITY_MONITOR_QUEUE_NAME)
        security_monitor_q.put(event)
                
        safety_q_name = SAFETY_BLOCK_QUEUE_NAME
        event = Event(source=BaseCommunicationGateway.event_source_name,
                      destination=safety_q_name,
                      operation="set_mission", parameters=self._mission
                      )
        security_monitor_q = self._queues_dir.get_queue(SECURITY_MONITOR_QUEUE_NAME)
        security_monitor_q.put(event)


class NavigationSystem(BaseNavigationSystem):
    """ класс навигационного блока """
    def _send_position_to_consumers(self):        
        control_q_name = CONTROL_SYSTEM_QUEUE_NAME
        event = Event(source=BaseCommunicationGateway.event_source_name,
                      destination=control_q_name,
                      operation="position_update", parameters=self._position
                      )
        security_monitor_q = self._queues_dir.get_queue(SECURITY_MONITOR_QUEUE_NAME)
        security_monitor_q.put(event)
      
        safety_q_name = SAFETY_BLOCK_QUEUE_NAME # замените на правильное название очереди
        event =  Event(source=BaseControlSystem.event_source_name,
                      destination=safety_q_name,
                      operation="position_update", parameters=self._position
                    ) # замените на код создания сообщения с координатами для системы управления 
                     # подсказка, требуемая операция - position_update
        security_monitor_q = self._queues_dir.get_queue(SECURITY_MONITOR_QUEUE_NAME)
        security_monitor_q.put(event)

class SafetyBlock(BaseSafetyBlock):
    """ класс ограничений безопасности """

    def _set_new_direction(self, direction: float):
        """ установка нового направления перемещения """
        self._log_message(LOG_INFO, f"текущие координаты: {self._position}")
        self._log_message(LOG_DEBUG, f"маршрутное задание: {self._mission}")
        self._log_message(LOG_DEBUG, f"состояние маршруте: {self._route}")
        # TODO реализовать контроль безопасности изменения направления

        if not self._position or not self._route:
            return
        
        current = self._position
        next = self._route.next_point()
        bearing = self._calculate_bearing(current, next)
        
        direction = max(bearing - 5, min(bearing + 5, direction))
                
        self._direction = direction
        # отправка сообщения с желаемым направлением
        self._send_direction_to_consumers()

    def _set_new_speed(self, speed: float):
        """ установка новой скорости """
        if not self._route:
            return

        speed = max(0, min(speed, self._route.calculate_speed()))

        self._speed = speed
        self._send_speed_to_consumers()

    def _send_speed_to_consumers(self):
        self._log_message(LOG_DEBUG, "отправляем скорость получателям")
        servos_q_name = SERVOS_QUEUE_NAME

        # отправка сообщения с желаемой скоростью
        event_speed = Event(source=self.event_source_name,
                            destination=servos_q_name,
                            operation="set_speed",
                            parameters=self._speed
                            )
        security_monitor_q = self._queues_dir.get_queue(SECURITY_MONITOR_QUEUE_NAME)
        security_monitor_q.put(event_speed)

    def _send_direction_to_consumers(self):
        self._log_message(LOG_DEBUG, "отправляем направление получателям")

        servos_q_name = SERVOS_QUEUE_NAME
        servos_q: Queue = self._queues_dir.get_queue(servos_q_name)

        # отправка сообщения с желаемой скоростью
        event_speed = Event(source=self.event_source_name,
                            destination=servos_q_name,
                            operation="set_direction",
                            parameters=self._direction
                            )
        security_monitor_q = self._queues_dir.get_queue(SECURITY_MONITOR_QUEUE_NAME)
        security_monitor_q.put(event_speed)

    def _lock_cargo(self, _):
        self._log_message(LOG_INFO, "Блокировка грузового отсека")
        self._send_lock_cargo_to_consumers()

    def _send_lock_cargo_to_consumers(self):
        self._log_message(LOG_DEBUG, "Отправляем команду блокировки в CargoBay")
        event = Event(
            source=self.event_source_name,
            destination=CARGO_BAY_QUEUE_NAME,
            operation="lock_cargo",
            parameters=None
        )
        security_monitor_q = self._queues_dir.get_queue(SECURITY_MONITOR_QUEUE_NAME)
        security_monitor_q.put(event)
        
    def _release_cargo(self, _):
        if not self._route or not self._route.route_finished:
            return
        self._send_release_cargo_to_consumers()

    def _send_release_cargo_to_consumers(self):
        self._log_message(LOG_DEBUG, "Отправляем команду выгрузки в CargoBay")
        event = Event(
            source=self.event_source_name,
            destination=CARGO_BAY_QUEUE_NAME,
            operation="release_cargo",
            parameters=None
        )
        security_monitor_q = self._queues_dir.get_queue(SECURITY_MONITOR_QUEUE_NAME)
        security_monitor_q.put(event)

    def _calculate_bearing(self, start: GeoPoint, end: GeoPoint):
        delta_longitude = end.longitude - start.longitude
        x = math.sin(math.radians(delta_longitude)) * \
            math.cos(math.radians(end.latitude))
        y = math.cos(math.radians(start.latitude)) * math.sin(math.radians(end.latitude)) - \
            math.sin(math.radians(start.latitude)) * math.cos(math.radians(end.latitude)) * \
            math.cos(math.radians(delta_longitude))
        initial_bearing_rad = math.atan2(x, y)

        # Преобразуем радианы в градусы
        initial_bearing_deg = math.degrees(initial_bearing_rad)

        # Нормализуем значение в диапазоне [0, 360]
        compass_bearing = (initial_bearing_deg + 360) % 360

        return compass_bearing

# %% [markdown]
# На этом модуль 3 завершён!
#
# Если у вас всё получилось, то вы создали защищённую автономную машинку - ещё уже не так-то просто использовать для нанесения критического ущерба людям и имуществу, потому что самые критические режимы проверяются вашим Ограничителем, а если вы ещё и внедрили Монитор Безопасности, то теперь злоумышленнику гораздо сложнее атаковать внутренние блоки, даже если он смог проникнуть в какую-то бортовую систему или внедрить вредоносный код.
#
# Осталось проверить эффективность получившейся защиты на полной трассе - в этом и заключается модуль 4 задания, для перехода к которому нужно открыть блокнот с именем cyberimmunity--autonomous-car-m4. Успеха!
